# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(1,"../src/")

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import path
from matplotlib.widgets import PolygonSelector, Button

from utilities import MyPolygonSelector

# %%
# %matplotlib widget

# %%
n = 13
m = 7

X, Y = np.meshgrid(range(n), range(m))

# %%
i = "bbbbbb"
def aaa():
    global i
    i = "aaaaaaaaa"

# %%
fig, ax = plt.subplots()

ax.scatter(X.flat, Y.flat)
fig.subplots_adjust(bottom=0.2)

selector = MyPolygonSelector(ax)

axadd = fig.add_axes((0.7, 0.05, 0.1, 0.075))
badd = Button(axadd, "Add Poly")
badd.on_clicked(aaa)
# Out:
# 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
i
# Out:
# 'bbbbbb'

# %%
aaa()

# %%
selector.select()

# %%
selector.polygons
# Out:
# []

# %%
for p in vort:
    p.

# %%
p = vort[0]

# %%
np.array([X.flat, Y.flat]).shape
